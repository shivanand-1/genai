# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanand-1/genai/blob/main/genai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gensim

# %%
# !pip install gensim

# %%
# !wget nlp.stanford.edu/data/glove.6B.zip

# %%
////////!unzip glove*.zip
# Out:
#   Cell In[1], line 1
#     ////////!unzip glove*.zip
#     ^
# SyntaxError: invalid syntax

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors

# %%
glove_input_file="glove.6B.300d.txt"
output_file="word2vec.txt"

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
glove2word2vec(glove_input_file,output_file)

# %%
from gensim.models import KeyedVectors
model=KeyedVectors.load_word2vec_format(output_file,binary=False)

# %%
model.most_similar(model["bengaluru"]-model["karnataka"]+model["hyderabad"],topn=1)
# Out:
# [('bengaluru', 0.69312584400177)]

# %%
# !git init
