# %%
from langchain_community.llms import Ollama

# %%
import yfinance as yf
import pandas as pd

# Sensex ticker
sensex = yf.download("^BSESN", start="2015-01-01", end="2025-01-01")

# Save to CSV
sensex.to_csv("sensex_data.csv")

print("CSV file saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import yfinance as yf
#       2 import pandas as pd
#       4 # Sensex ticker
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
llm=Ollama(model="kimi-k2.5:cloud ")

# %%
# !pip install yfinance
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------------- -------------- 1.0/1.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.7 MB/s  0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15702 sha256=00f4626db6dc751af5dd5b0fbbcb874a2eabe60662838d32fa245adcb504d69f
#   Stored in directory: c:\users\shiva\appdata\local\pip\cache\wheels\42\d6\84\bf57a755f4569494cd00de4bb46ef064874823f4d19c82e960
# Successfully built multitasking
# ...
#
#    ---------------------------------------- 0/6 [peewee]
# ...

# %%
import yfinance as yf
import pandas as pd

# Sensex ticker
sensex = yf.download("^BSESN", start="2015-01-01", end="2025-01-01")

# Save to CSV
sensex.to_csv("sensex_data.csv")

print("CSV file saved successfully!")
# Out:
# [*********************100%***********************]  1 of 1 completed
# CSV file saved successfully!

# %%
data=pd.read_csv("sensex_data.csv")

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#            Price            Close             High              Low  \
# 0         Ticker           ^BSESN           ^BSESN           ^BSESN
# 1           Date              NaN              NaN              NaN
# 2     2015-01-02  27887.900390625  27937.470703125  27519.259765625
# 3     2015-01-05    27842.3203125  28064.490234375  27786.849609375
# 4     2015-01-06    26987.4609375    27698.9296875  26937.060546875
# ...          ...              ...              ...              ...
# 2456  2024-12-24    78472.8671875     78877.359375    78397.7890625
# 2457  2024-12-26    78472.4765625    78898.3671875    78173.3828125
# 2458  2024-12-27    78699.0703125    79043.1484375     78598.546875
# 2459  2024-12-30    78248.1328125     79092.703125    78077.1328125
# 2460  2024-12-31    78139.0078125      78305.34375    77560.7890625
#
#                  Open  Volume
# 0              ^BSESN  ^BSESN
# 1                 NaN     NaN
# 2     27521.279296875    7400
# ...

# %%
#exctring only the structral info
scheme_info={
    "columns":df.columns.to_list(),
    "dtypes":df.dtypes.astype(str).to_dict(),
    "missing_values":df.isnull().sum(),
    "shape":df.shape
}
print(scheme_info)
# Out:
# {'columns': ['Price', 'Close', 'High', 'Low', 'Open', 'Volume'], 'dtypes': {'Price': 'object', 'Close': 'object', 'High': 'object', 'Low': 'object', 'Open': 'object', 'Volume': 'object'}, 'missing_values': Price     0
# Close     1
# High      1
# Low       1
# Open      1
# Volume    1
# dtype: int64, 'shape': (2461, 6)}

# %%
prompt=f"""
you are the data scientist 
and here the dataset in the metadata
:{scheme_info} 
writhe the pyhton code using pandas matplotlib and seaborn to:
1:generate the summary of the status 
2:plot the distubution of the normal columns
3:plot the coreation heatmap
4:indefy the missing values vusulaly
only the returnt the executable code """

# %%
generated_code=llm.invoke(prompt)

# %%
print(generated_code)
# Out:
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import numpy as np
#
# # Load dataset (update path as needed)
# # df = pd.read_csv('your_data.csv')
#
# # Data preprocessing: Convert object columns to numeric
# numeric_cols = ['Price', 'Close', 'High', 'Low', 'Open', 'Volume']
#
# for col in numeric_cols:
#     # Remove commas/currency symbols and convert to float
#     df[col] = pd.to_numeric(df[col].astype(str).str.replace('[^\d.-]', '', regex=True), errors='coerce')
#
# # 1. Generate Summary Statistics
# print("=" * 50)
# print("DATASET SUMMARY")
# print("=" * 50)
# print(f"\nShape: {df.shape[0]} rows, {df.shape[1]} columns")
# print(f"\nColumn Data Types:")
# print(df.dtypes)
# print(f"\nMissing Values Count:")
# print(df.isnull().sum())
# print(f"\nDescriptive Statistics:")
# print(df.describe())
#
# # 2. Plot Distributions
# plt.figure(figsize=(16, 10))
# for i, col in enumerate(numeric_cols, 1):
#     plt.subplot(2, 3, i)
# ...
