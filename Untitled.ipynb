# %%
100//10
# Out:
# 10

# %%
100%10
# Out:
# 0

# %%
123%10
# Out:
# 3

# %%
123//10
# Out:
# 12

# %%
12//10
# Out:
# 1

# %%
12%10
# Out:
# 2

# %%
2%20
# Out:
# 2

# %%
for i in range(0,5):
    for j in range(0,5):
        if i==j or i<j:
            print("*",end="") 
    print()
# Out:
# *****
# ****
# ***
# **
# *
