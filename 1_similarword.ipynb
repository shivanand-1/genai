# %%
# !pip install gensim

# %%
# !pip install --upgrade scipy

# %%
# !python.exe -m pip install --upgrade pip

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
input_file='glove.6B.100d.txt'
word2vec='glove.6B.100d.txt'
glove2word2vec(input_file,word2vec)

# %%
# !Ignoring invalid distribution ~umpy
# !Ignoring invalid distribution ~5py

# %%
# !pip uninstall numpy scipy gensim -y
# !pip install numpy==1.26.4
# !pip install scipy==1.10.1
# !pip install gensim==4.3.0

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
input_file=r'"C:\Users\shiva\Downloads\glove.6B.50d.txt"'
word2vec=r'C:\Users\shiva\Downloads\glove.word2vec.6B.50d.txt'
glove2word2vec(input_file,word2vec)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_38104\2417835121.py:5: DeprecationWarning: Call to deprecated `glove2word2vec` (KeyedVectors.load_word2vec_format(.., binary=False, no_header=True) loads GLoVE text vectors.).
#   glove2word2vec(input_file,word2vec)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 5
#       3 input_file=r'"C:\Users\shiva\Downloads\glove.6B.50d.txt"'
#       4 word2vec=r'C:\Users\shiva\Downloads\glove.word2vec.6B.50d.txt'
# ----> 5 glove2word2vec(input_file,word2vec)
#
# File ~\anaconda3\Lib\site-packages\gensim\utils.py:1522, in deprecated.<locals>.decorator.<locals>.new_func1(*args, **kwargs)
#    1515 @wraps(func)
#    1516 def new_func1(*args, **kwargs):
#    1517     warnings.warn(
#    1518         fmt.format(name=func.__name__, reason=reason),
#    1519         category=DeprecationWarning,
#    1520         stacklevel=2
# ...

# %%
import os
print(os.getcwd())

# %%
with open(r"C:\Users\shiva\Documents\glove.6B.100d.txt", "r", encoding="utf-8") as f:
    print(f.readline())

# %%
with open(r"C:\Users\shiva\Downloads\glove.6B.100d.txt", "w") as f:
    f.write("working")

# %%
from gensim.models import KeyedVectors

model = KeyedVectors.load_word2vec_format(
       r'C:\Users\shiva\Downloads\glove.6B.50d.txt',
       no_header=True  # GloVe files have no header line
   )
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 3
#       1 from gensim.models import KeyedVectors
# ----> 3 model = KeyedVectors.load_word2vec_format(
#       4        r'C:\Users\shiva\Downloads\glove.6B.50d.txt',
#       5        no_header=True  # GloVe files have no header line
#       6    )
#
# File ~\anaconda3\Lib\site-packages\gensim\models\keyedvectors.py:1719, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1672 @classmethod
#    1673 def load_word2vec_format(
#    1674         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1675         limit=None, datatype=REAL, no_header=False,
#    1676     ):
#    1677     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1678
#    1679     Warnings
#    (...)
# ...

# %%
# Test if you can even open it
with open(r'C::\Users\shiva\Downloads\glove\glove.6B.50d.txt', 'r', encoding='utf-8') as f:
    print(f.readline())  # Should print the first line
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Test if you can even open it
# ----> 2 with open(r'C:\glove\glove.6B.50d.txt', 'r', encoding='utf-8') as f:
#       3     print(f.readline())
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\glove\\glove.6B.50d.txt'

# %%
import gensim

# %%
# !wget nlp.stanford.edu/data/glove.6B.zip
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
