# %%
from sentence_transformers import SentenceTransformer

# %%
model=SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model=SentenceTransformer('all-MiniLM-L6-v2')
#
# NameError: name 'SentenceTransformer' is not defined

# %%
import sentence_transformers
print(sentence_transformers.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import sentence_transformers
#       2 print(sentence_transformers.__version__)
#
# File ~\anaconda3\envs\rag_env\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#      18     CrossEncoderModelCardData,
#      19     CrossEncoderTrainer,
#      20     CrossEncoderTrainingArguments,
#      21 )
# ...

# %%
# !pip install sentence-transformers

# %%
import sentence_transformers
print(sentence_transformers.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import sentence_transformers
#       2 print(sentence_transformers.__version__)
#
# File ~\anaconda3\envs\rag_env\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#      16 from sentence_transformers.cross_encoder import (
#      17     CrossEncoder,
#      18     CrossEncoderModelCardData,
#      19     CrossEncoderTrainer,
#      20     CrossEncoderTrainingArguments,
#      21 )
# ...

# %%
# !pip install datasets --upgrade
# Out:
# ...
#   Using cached datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/527.0 kB ? eta -:--:--
#    ---------------------------------------- 527.0/527.0 kB 1.1 MB/s  0:00:00
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# ...
#
#   Attempting uninstall: fsspec
#
#     Found existing installation: fsspec 2026.3.0
#
#     Uninstalling fsspec-2026.3.0:
#
#       Successfully uninstalled fsspec-2026.3.0
#
#    ---------------------------------------- 0/2 [fsspec]
#    ---------------------------------------- 0/2 [fsspec]
#    ---------------------------------------- 0/2 [fsspec]
#    ---------------------------------------- 0/2 [fsspec]
#    ---------------------------------------- 0/2 [fsspec]
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
se="the future of AI is bright."
vector=model.encode(se)
print(vector[:5])
# Out:
# [-0.03986632 -0.03020747  0.0322851  -0.00241171  0.01722387]

# %%
import chromadb
client=chromadb.Client()
collection=client.create_collection(name="knowledge")

# %%
documents = [
    "Machine learning is a subset of AI that focuses on data.",
    "A neural network mimics the human brain to learn patterns.",
    "Python is a popular programming language for data science.",
    "Docker helps developers containerize applications.",
    "Vegetables are good for your health and provide vitamins."
]

ids = ["doc1", "doc2", "doc3", "doc4", "doc5"]

# %%
embeddings=model.encode(documents)
collection.add(
    documents=documents,
    embeddings=embeddings,
    ids=ids
)

print("Documents added to the Vector Database!")  
print(k)
# Out:
# Documents added to the Vector Database!
# None

# %%
query="how do computers leann from experience"
query_en=model.encode(query)
print(query_en[:5])
# Out:
# [-0.0021476  -0.03742222  0.01535772 -0.01152858  0.02368601]

# %%
results = collection.query(
    query_embeddings=[query_en],
    n_results=2 # Return the top 2 matches
)
p=results
str(p)
# Out:
# "{'ids': [['doc1', 'doc2']], 'embeddings': None, 'documents': [['Machine learning is a subset of AI that focuses on data.', 'A neural network mimics the human brain to learn patterns.']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.4229464530944824, 1.4465572834014893]]}"

# %%
print(p[:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(p[:2])
#
# TypeError: unhashable type: 'slice'
