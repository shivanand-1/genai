# %%
import gensim.downloader as api

# %%
from gensim.models import KeyedVectors

# %%
model=api.load("glove-wiki-gigaword-100")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
import random
king="people"
similar=model.most_similar(king,topn=10)
def find_similar(similar):
    ki=[words for words,_ in similar]
    random.shuffle(ki)
    print(ki[:5])
    similar_words=f"the word {king}"
    similar_words+=f"the words are the {ki[:-1]} and {ki[-1]}"
    for i in similar_words:
        if "[" or "]" in i:
            kio=i.replace("[","").replace("]","")
            print(kio,end="")
d=find_similar(similar)
# Out:
# ['they', 'those', 'some', 'all', 'them']
# the word peoplethe words are the 'they', 'those', 'some', 'all', 'them', 'residents', 'families', 'many', 'than' and others

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 import random
# ----> 2 random.shuffle(d)
#
# File ~\anaconda3\Lib\random.py:380, in Random.shuffle(self, x)
#     377 """Shuffle list x in place, and return None."""
#     379 randbelow = self._randbelow
# --> 380 for i in reversed(range(1, len(x))):
#     381     # pick an element in x[:i+1] with which to exchange x[i]
#     382     j = randbelow(i + 1)
#     383     x[i], x[j] = x[j], x[i]
#
# TypeError: object of type 'NoneType' has no len()
